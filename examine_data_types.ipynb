# %%
import json
import random
import pydicom as dicom
import matplotlib.pylab as plt
import matplotlib.image as mpimg

# %%
def view(folder, img_id):
    
    path = f'dcm_data/{folder}/{img_id}'
    ds = dicom.dcmread(path)

    if ds.pixel_array.ndim == 3:
        plt.imshow(ds.pixel_array[:,:,:])
    elif ds.pixel_array.ndim == 4:
        print(ds.pixel_array.shape)
        i = random.randint(0, ds.pixel_array.shape[0]-1)
        plt.imshow(ds.pixel_array[i,:,:,:])

# %%
with open("dcm_data_types_thres0.71.json", "r") as f:
    data_type_dict = json.load(f)

# %%
def check_type(type_i, ith_file):

    files = data_type_dict[str(type_i)]
    print(files[ith_file])
    view(files[ith_file].split("/")[0], files[ith_file].split("/")[1])

# %%
for typ, data in data_type_dict.items():
    print(f"Type {typ} has {len(data)} files")
# Out:
# Type 1 has 393 files
# Type 2 has 96 files
# Type 3 has 41 files
# Type 4 has 30 files
# Type 5 has 20 files
# Type 6 has 21 files
# Type 7 has 16 files
# Type 8 has 19 files
# Type 9 has 12 files
# Type 10 has 11 files
# Type 11 has 5 files
# Type 12 has 3 files
# Type 13 has 2 files
# Type 14 has 2 files
# Type 15 has 2 files
# Type 16 has 2 files
# Type 17 has 2 files
# Type 18 has 2 files
# Type 19 has 2 files
# Type 20 has 2 files
# Type 21 has 2 files
# Type 22 has 2 files
# Type 23 has 1 files
# Type 24 has 1 files
# Type 25 has 1 files
# Type 26 has 1 files
# Type 27 has 1 files
# Type 28 has 1 files
# Type 29 has 1 files
# Type 30 has 1 files
# Type 31 has 1 files
# Type 32 has 1 files
# Type 33 has 1 files
# Type 34 has 1 files
# Type 35 has 1 files
# Type 36 has 1 files
# Type 37 has 1 files
# Type 38 has 1 files
# Type 39 has 1 files
# Type 40 has 1 files
# Type 41 has 1 files
# Type 42 has 1 files
# Type 43 has 1 files
# Type 44 has 1 files
# Type 45 has 1 files
# Type 46 has 1 files
# Type 47 has 1 files
# Type 48 has 1 files
# Type 49 has 1 files
# Type 50 has 1 files
# Type 51 has 1 files
# Type 52 has 1 files
# Type 53 has 1 files
# Type 54 has 1 files
# Type 55 has 1 files
# Type 56 has 1 files
# Type 57 has 1 files
# Type 58 has 1 files
# Type 59 has 1 files
# Type 60 has 1 files
# Type 61 has 1 files
# Type 62 has 1 files
# Type 63 has 1 files

# %% [markdown]
# ## check type 1
# **Type 1 has 393 files**

# %%
check_type(1, 392)
# Out:
# 10651_20171118/IM-0001-0043.dcm
# (37, 720, 960, 3)

# %% [markdown]
# ## check type 2
# **Type 2 has 96 files**

# %%
check_type(2, 62)
# Out:
# 20218_20171201/IM-0001-0072.dcm

# %% [markdown]
# ## check type 3
# **Type 3 has 41 files**

# %%
check_type(3, 24)
# Out:
# 21104_20180322/IM-0001-0023.dcm

# %%
check_type(3, 20)
# Out:
# 22444_20180404/IM-0001-0056.dcm

# %% [markdown]
# ## check type 4
# **Type 4 has 30 files**

# %%
check_type(4, 25)
# Out:
# 14369_20180420/IM-0001-0050.dcm

# %% [markdown]
# ## check type 5
# **Type 5 has 20 files**

# %%
check_type(5, 8)
# Out:
# 22444_20180404/IM-0001-0033.dcm
# (38, 720, 960, 3)

# %% [markdown]
# ## check type 6
# **Type 6 has 21 files**

# %%
check_type(6, 20)
# Out:
# 20596_20171118/IM-0001-0038.dcm
# (34, 720, 960, 3)

# %%
check_type(6, 19)
# Out:
# 20596_20171118/IM-0001-0040.dcm

# %% [markdown]
# ## check type 7
# **Type 7 has 16 files**

# %%
check_type(7, 5)
# Out:
# 10377_20180815/IM-0002-0093.dcm

# %% [markdown]
# ## check type 8
# **Type 8 has 19 files**

# %%
check_type(8, 14)
# Out:
# 15751_20180728/IM-0001-0091.dcm
# (74, 720, 960, 3)

# %% [markdown]
# ## check type 9
# **Type 9 has 12 files**

# %%
check_type(9, 10)
# Out:
# 10026_20171208/IM-0001-0017.dcm

# %% [markdown]
# ## check type 10
# **Type 10 has 11 files**

# %%
check_type(10, 7)
# Out:
# 20218_20171201/IM-0001-0001.dcm
